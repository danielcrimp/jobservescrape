# %%
import pandas as pd

# %%
df =pd.read_csv('jobs.csv')

# %%
df
# Out:
#       Unnamed: 0                 jid  \
# 0              0  C40441B39EF9DC8730
# 1              0  67B2B8C9A90309D587
# 2              0  0ACCE919D09D44CD42
# 3              0  2602604A682569EAD0
# 4              0  050CA9200FFFBC40AF
# ...          ...                 ...
# 1018           0  860128EF608D6510E9
# 1019           0  CEC36A53D853BF7CEE
# 1020           0  4BD6A42D456C816A65
# 1021           0  FFD341D7A5B790124B
# 1022           0  64C5B02D0A05DEEE17
#
#                                                   title  \
# 0                                       Head of Content
# 1                 Senior Renewables Analyst Opportunity
# 2                                       Head of Content
# 3                         Senior Infrastructure Analyst
# 4                 Senior Renewables Analyst Opportunity
# ...                                                 ...
# 1018                  Business Migration Assurance Lead
# 1019                       Platform Training Specialist
# ...

# %%
df['sal'] = df['sal'].str.replace('\r\n\t\t\t\t\t\t','')

# %%
filt = df['sal'].str.contains('Rate')
df[filt]
# Out:
#       Unnamed: 0                 jid  \
# 2              0  0ACCE919D09D44CD42
# 4              0  050CA9200FFFBC40AF
# 5              0  CD8D90A6B308387C18
# 6              0  DA87099CC81E257603
# 10             0  1740D86FA9B1A029B4
# ...          ...                 ...
# 987            0  52AFB8A9A43B2B145C
# 988            0  C3EDBF5729FD880249
# 1001           0  65FBC181B72B6E8AE9
# 1004           0  57101C5B11A287A855
# 1014           0  AB1802F97DA63AC3EE
#
#                                                   title  \
# 2                                       Head of Content
# 4                 Senior Renewables Analyst Opportunity
# 5        Mid-Level Full Stack Developer - Angular, .Net
# 6                     Designer learning and development
# 10        Data Scientist - Research and Innovation Lead
# ...                                                 ...
# 987                             Data Governance Analyst
# 988                                Data Quality Analyst
# ...
